# %%
import pandas as pd

# %%
movies_metadata=pd.read_csv("movies_metadata.csv", low_memory=False)
ratings=pd.read_csv("ratings.csv")

# %%
movies_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 30385  False                                                NaN        0
# 888    False                                                NaN  2238813
# 40568  False                                                NaN        0
# 19580  False  {'id': 38451, 'name': 'Charlie Chan (Warner Ol...        0
# 18061  False                                                NaN        0
#
#                                                   genres  \
# 30385                     [{'id': 35, 'name': 'Comedy'}]
# 888    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 40568  [{'id': 16, 'name': 'Animation'}, {'id': 80, '...
# 19580  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 18061                      [{'id': 18, 'name': 'Drama'}]
#
#                               homepage      id    imdb_id original_language  \
# 30385                              NaN  195413  tt0052921                it
# 888                                NaN    6620  tt0047437                en
# 40568  http://www.towerdocumentary.com  381028  tt5116410                en
# 19580                              NaN   33391  tt0024968                en
# 18061                              NaN   42605  tt0064400                en
#
#                original_title  \
# 30385             L'Impiegato
# 888                   Sabrina
# 40568                   Tower
# 19580  Charlie Chan in London
# 18061                  Hamlet
#
#                                                 overview  ... release_date  \
# 30385                                                NaN  ...   1960-01-20
# 888    Linus and David Larrabee are the two sons of a...  ...   1954-09-28
# 40568  Combining archival footage with rotoscopic ani...  ...   2016-03-13
# 19580  After receiving congratulations from the Home ...  ...   1934-09-12
# 18061  Tony Richardson's Hamlet is based on his own s...  ...   1969-12-21
#
#           revenue runtime                                   spoken_languages  \
# 30385         0.0     NaN                                                 []
# 888    10000000.0   113.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 40568         0.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19580         0.0    79.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18061         0.0   117.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 30385  Released                                                NaN
# 888    Released  ...the chauffeur's daughter who learned her st...
# 40568  Released                                                NaN
# 19580  Released          When all others failed, they turned to...
# 18061  Released                                 From the author of
#
#                         title  video vote_average vote_count
# 30385             L'Impiegato  False          0.0        0.0
# 888                   Sabrina  False          7.4      284.0
# 40568                   Tower  False          8.1       50.0
# 19580  Charlie Chan in London  False          6.1       10.0
# 18061                  Hamlet  False          6.1        7.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 9994345   103075      415     4.0   836480525
# 16687174  173593     2763     4.0  1486565329
# 22815869  237060     2268     4.0  1013106282
# 18957015  196821      318     5.0   952129730
# 1492198    15347      648     3.5  1131590718

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34172\808813721.py in <module>
# ----> 1 kaggle_metadata.dtypes
#
# NameError: name 'kaggle_metadata' is not defined
